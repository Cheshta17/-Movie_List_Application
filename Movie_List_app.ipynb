# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# for jupyter notebook widgets
import ipywidgets as widgets
from ipywidgets import interact
from ipywidgets import interact_manual

# for Interactive Shells
from IPython.display import display

# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
pd.options.display.max_columns = 50

# %%
display (os.getcwd())
# Out:
# 'C:\\Users\\deepak'

# %%
# lets read the dataset
os.chdir('C:\Movie_list_app\\')
data = pd.read_csv('movie_metadata.csv')
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0          NaN                      Documentary
#
#       actor_1_name                                        movie_title  \
# 0      CCH Pounder                                            Avatar
# 1      Johnny Depp          Pirates of the Caribbean: At World's End
# 2  Christoph Waltz                                           Spectre
# 3        Tom Hardy                             The Dark Knight Rises
# 4      Doug Walker  Star Wars: Episode VII - The Force Awakens    ...
#
#    num_voted_users  cast_total_facebook_likes          actor_3_name  \
# 0           886204                       4834             Wes Studi
# 1           471220                      48350        Jack Davenport
# 2           275868                      11700      Stephanie Sigman
# 3          1144337                     106759  Joseph Gordon-Levitt
# 4                8                        143                   NaN
#
#    facenumber_in_poster                                      plot_keywords  \
# 0                   0.0             avatar|future|marine|native|paraplegic
# 1                   0.0  goddess|marriage ceremony|marriage proposal|pi...
# 2                   1.0                bomb|espionage|sequel|spy|terrorist
# 3                   0.0  deception|imprisonment|lawlessness|police offi...
# 4                   0.0                                                NaN
#
#                                      movie_imdb_link  num_user_for_reviews  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...                3054.0
# 1  http://www.imdb.com/title/tt0449088/?ref_=fn_t...                1238.0
# 2  http://www.imdb.com/title/tt2379713/?ref_=fn_t...                 994.0
# 3  http://www.imdb.com/title/tt1345836/?ref_=fn_t...                2701.0
# 4  http://www.imdb.com/title/tt5289954/?ref_=fn_t...                   NaN
#
#   language country content_rating       budget  title_year  \
# 0  English     USA          PG-13  237000000.0      2009.0
# 1  English     USA          PG-13  300000000.0      2007.0
# 2  English      UK          PG-13  245000000.0      2015.0
# 3  English     USA          PG-13  250000000.0      2012.0
# 4      NaN     NaN            NaN          NaN         NaN
#
#    actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes
# 0                   936.0         7.9          1.78                 33000
# 1                  5000.0         7.1          2.35                     0
# 2                   393.0         6.8          2.35                 85000
# 3                 23000.0         8.5          2.35                164000
# 4                    12.0         7.1           NaN                     0

# %%
# lets check the shape
print(data.shape)
# Out:
# (5043, 28)

# %%
# lets check the column wise info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
#  13  cast_total_facebook_likes  5043 non-null   int64
#  14  actor_3_name               5020 non-null   object
#  15  facenumber_in_poster       5030 non-null   float64
#  16  plot_keywords              4890 non-null   object
#  17  movie_imdb_link            5043 non-null   object
#  18  num_user_for_reviews       5022 non-null   float64
#  19  language                   5031 non-null   object
#  20  country                    5038 non-null   object
#  21  content_rating             4740 non-null   object
#  22  budget                     4551 non-null   float64
#  23  title_year                 4935 non-null   float64
#  24  actor_2_facebook_likes     5030 non-null   float64
#  25  imdb_score                 5043 non-null   float64
#  26  aspect_ratio               4714 non-null   float64
#  27  movie_facebook_likes       5043 non-null   int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 1.1+ MB

# %%
data.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# check duplicated data
data.duplicated().sum()

# drop duplicates
data = data.drop_duplicates()

# %%
data.nunique()
# Out:
# color                           2
# director_name                2398
# num_critic_for_reviews        528
# duration                      191
# director_facebook_likes       435
# actor_3_facebook_likes        906
# actor_2_name                 3032
# actor_1_facebook_likes        878
# gross                        4035
# genres                        914
# actor_1_name                 2097
# movie_title                  4917
# num_voted_users              4826
# cast_total_facebook_likes    3978
# actor_3_name                 3521
# facenumber_in_poster           19
# plot_keywords                4760
# movie_imdb_link              4919
# num_user_for_reviews          954
# language                       47
# country                        65
# content_rating                 18
# budget                        439
# title_year                     91
# actor_2_facebook_likes        917
# imdb_score                     78
# aspect_ratio                   22
# movie_facebook_likes          876
# dtype: int64

# %%
data.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4949.000000  4983.000000              4895.000000
# mean               139.890079   107.213325               688.679060
# std                121.477586    25.248775              2821.649616
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               192.000000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4975.000000             4991.000000  4.124000e+03
# mean               639.900905             6556.939892  4.832565e+07
# std               1643.298282            15061.586700  6.796483e+07
# min                  0.000000                0.000000  1.620000e+02
# 25%                133.000000              611.500000  5.304835e+06
# 50%                369.000000              984.000000  2.544575e+07
# 75%                635.000000            11000.000000  6.231942e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     4.998000e+03                4998.000000           4985.000000
# mean      8.347020e+04                9676.941176              1.368907
# std       1.380866e+05               18165.404578              2.014623
# min       5.000000e+00                   0.000000              0.000000
# 25%       8.560000e+03                1405.500000              0.000000
# 50%       3.426050e+04                3085.500000              1.000000
# 75%       9.612075e+04               13740.500000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           4977.000000  4.511000e+03  4891.000000
# mean             272.014667  3.974787e+07  2002.468820
# std              377.776210  2.069689e+08    12.475235
# min                1.000000  2.180000e+02  1916.000000
# 25%               64.000000  6.000000e+06  1999.000000
# 50%              156.000000  2.000000e+07  2005.000000
# 75%              324.000000  4.500000e+07  2011.000000
# max             5060.000000  1.221550e+10  2016.000000
#
#        actor_2_facebook_likes   imdb_score  aspect_ratio  movie_facebook_likes
# count             4985.000000  4998.000000   4671.000000           4998.000000
# mean              1642.998796     6.441056      2.221417           7487.430172
# std               4030.925303     1.124107      1.391185          19290.726563
# min                  0.000000     1.600000      1.180000              0.000000
# 25%                280.000000     5.800000      1.850000              0.000000
# 50%                595.000000     6.600000      2.350000            162.500000
# 75%                917.000000     7.200000      2.350000           3000.000000
# max             137000.000000     9.500000     16.000000         349000.000000

# %%
data.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# aspect_ratio                 float64
# movie_facebook_likes           int64
# dtype: object

# %%
eda = data.copy()
eda = data.dropna()

# %%
eda['title_year'] = eda['title_year'].astype(int)

# %%
top10_imdb = eda.sort_values(by='imdb_score', ascending=False)
top10_imdb = top10_imdb[['movie_title','title_year', 'genres', 'director_name', 'imdb_score']].reset_index(drop=True)
top10_imdb = top10_imdb.head(10)
top10_imdb
# Out:
#                                        movie_title  title_year  \
# 0                        The Shawshank Redemption         1994
# 1                                   The Godfather         1972
# 2                                 The Dark Knight         2008
# 3                          The Godfather: Part II         1974
# 4                  The Good, the Bad and the Ugly         1966
# 5   The Lord of the Rings: The Return of the King         2003
# 6                                    Pulp Fiction         1994
# 7                                Schindler's List         1993
# 8  Star Wars: Episode V - The Empire Strikes Back         1980
# 9                                      Fight Club         1999
#
#                             genres         director_name  imdb_score
# 0                      Crime|Drama        Frank Darabont         9.3
# 1                      Crime|Drama  Francis Ford Coppola         9.2
# 2      Action|Crime|Drama|Thriller     Christopher Nolan         9.0
# 3                      Crime|Drama  Francis Ford Coppola         9.0
# 4                          Western          Sergio Leone         8.9
# 5   Action|Adventure|Drama|Fantasy         Peter Jackson         8.9
# 6                      Crime|Drama     Quentin Tarantino         8.9
# 7          Biography|Drama|History      Steven Spielberg         8.9
# 8  Action|Adventure|Fantasy|Sci-Fi        Irvin Kershner         8.8
# 9                            Drama         David Fincher         8.8

# %%
sns.barplot(y='movie_title', x='imdb_score', data=top10_imdb, palette='Blues')
plt.title('Top 10 Movies with Highest IMBD Score', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Top 10 Movies with Highest IMBD Score')

# %%
eda['profit'] = eda['gross'] - eda['budget']

# convert proft to milion
eda['profit'] = round(eda['profit']/1000000,2)
top10profit = eda[['profit', 'movie_title','title_year', 'director_name']].sort_values(by='profit', ascending=False).reset_index(drop=True).head(10)


top10profit
# Out:
#    profit                                 movie_title  title_year  \
# 0  523.51                                     Avatar         2009
# 1  502.18                             Jurassic World         2015
# 2  458.67                                    Titanic         1997
# 3  449.94         Star Wars: Episode IV - A New Hope         1977
# 4  424.45                 E.T. the Extra-Terrestrial         1982
# 5  403.28                               The Avengers         2012
# 6  377.78                              The Lion King         1994
# 7  359.54  Star Wars: Episode I - The Phantom Menace         1999
# 8  348.32                            The Dark Knight         2008
# 9  330.00                           The Hunger Games         2012
#
#        director_name
# 0      James Cameron
# 1    Colin Trevorrow
# 2      James Cameron
# 3       George Lucas
# 4   Steven Spielberg
# 5        Joss Whedon
# 6       Roger Allers
# 7       George Lucas
# 8  Christopher Nolan
# 9          Gary Ross

# %%
sns.barplot(x='profit', y='movie_title', data=top10profit, palette='Blues')
plt.xlabel('Profit (in Milion)')
plt.title('Top 10 Movie with Highest Profit', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Top 10 Movie with Highest Profit')

# %%
loss = eda[['profit', 'movie_title', 'title_year', 'director_name']].sort_values(by='profit', ascending=True).reset_index(drop=True).head(10)
loss['profit'] = round(loss['profit']/1000,2)  #convert to bilion
loss = loss.sort_values(by='profit', ascending=False)
loss
# Out:
#    profit              movie_title  title_year    director_name
# 9   -0.55               Red Cliff         2008         John Woo
# 7   -0.70                   Tango         1998     Carlos Saura
# 8   -0.70  Kabhi Alvida Naa Kehna         2006      Karan Johar
# 6   -0.99           Godzilla 2000         1999    Takao Okawara
# 5   -1.10                   Akira         1988  Katsuhiro Ôtomo
# 4   -2.13                Steamboy         2004  Katsuhiro Ôtomo
# 3   -2.40       Princess Mononoke         1997   Hayao Miyazaki
# 2   -2.50                Fateless         2005     Lajos Koltai
# 1   -4.20          Lady Vengeance         2005   Chan-wook Park
# 0  -12.21                The Host         2006     Joon-ho Bong

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='profit', y='movie_title', data=loss, palette='Blues')
plt.xlabel('Loss (in Bilion)')
plt.title('Top 10 Movies with Highest Loss', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Top 10 Movies with Highest Loss')

# %%
eda['gross'] = round(eda['gross']/1000000,2)
top10gross = eda[['gross', 'movie_title', 'title_year']].sort_values(by='gross', ascending=False).reset_index(drop=True).head(10)

# %%
sns.barplot(x='gross', y='movie_title', data=top10gross, palette='Blues_d')
# Out:
# <AxesSubplot:xlabel='gross', ylabel='movie_title'>

# %%
eda['language'].value_counts()
# Out:
# English       3566
# French          34
# Spanish         23
# Mandarin        14
# German          10
# Japanese        10
# Cantonese        7
# Italian          7
# Portuguese       5
# Hindi            5
# Korean           5
# Norwegian        4
# Danish           3
# Thai             3
# Persian          3
# Dutch            3
# Indonesian       2
# Aboriginal       2
# Dari             2
# Mongolian        1
# None             1
# Romanian         1
# Vietnamese       1
# Arabic           1
# Hebrew           1
# Zulu             1
# Czech            1
# Russian          1
# Filipino         1
# Maya             1
# Kazakh           1
# Hungarian        1
# Aramaic          1
# Bosnian          1
# Name: language, dtype: int64

# %%
eda['languages'] = np.where(eda['language'] == 'English', 'English', 'Foreign')
eda['languages'].value_counts()
# Out:
# English    3566
# Foreign     157
# Name: languages, dtype: int64

# %%
# group by languages and sum profit
eda.groupby('languages').agg(proft_sum=('profit','sum'), profit_mean=('profit','mean')).reset_index()
# Out:
#   languages  proft_sum  profit_mean
# 0   English   52912.17    14.837961
# 1   Foreign  -29644.07  -188.815732

# %%
# group by languages and sum gross
gross_lang = eda.groupby('languages').agg(gross_sum=('gross','sum'), gross_mean=('gross','mean')).reset_index()
gross_lang
# Out:
#   languages  gross_sum  gross_mean
# 0   English  194322.37   54.493093
# 1   Foreign    1061.90    6.763694

# %%
imdb_lang = eda.groupby('languages').agg(imdb=('imdb_score','mean')).reset_index()
imdb_lang
# Out:
#   languages      imdb
# 0   English  6.427510
# 1   Foreign  7.332484

# %%
data['duration'].describe()
# Out:
# count    4983.000000
# mean      107.213325
# std        25.248775
# min         7.000000
# 25%        93.000000
# 50%       103.000000
# 75%       118.000000
# max       511.000000
# Name: duration, dtype: float64

# %%
def duration(x, quantile):
    q1, q3 = quantile
    try:
        if x >= q3:
            return 'long'
        elif x >= q1:
            return 'medium'
        else:
            return 'short'
    except exception:
        return 'Unknown'

eda['duration_type'] = eda['duration'].apply(lambda x: duration(x, eda['duration'].quantile([0.33, 0.66])))

# %%
eda['duration_type'].value_counts()
# Out:
# long      1294
# medium    1235
# short     1194
# Name: duration_type, dtype: int64

# %%
profit_duration = eda.groupby('duration_type').agg(profit_sum=('profit','sum'), profit_mean=('profit','mean')).reset_index()
profit_duration
# Out:
#   duration_type  profit_sum  profit_mean
# 0          long    17406.10    13.451391
# 1        medium    -8243.69    -6.675053
# 2         short    14105.69    11.813811

# %%
sns.barplot(x='duration_type', y='profit_sum', data=profit_duration, palette='Blues')
plt.ylabel('Profit Sum (Milion USD)')
plt.show()

sns.barplot(x='duration_type', y='profit_mean', data=profit_duration, palette='Blues')
plt.ylabel('Profit Mean (Milion USD)')
plt.show()

# %%
gross_duration = eda.groupby('duration_type').agg(gross_sum=('gross','sum'), gross_mean=('gross','mean')).reset_index()
gross_duration
# Out:
#   duration_type  gross_sum  gross_mean
# 0          long   96354.17   74.462264
# 1        medium   52231.09   42.292381
# 2         short   46799.01   39.195151

# %%
sns.barplot(x='duration_type', y='gross_sum', data=gross_duration, palette='Blues')
plt.ylabel('Gross Sum (Milion USD)')
plt.show()

sns.barplot(x='duration_type', y='gross_mean', data=gross_duration, palette='Blues')
plt.ylabel('Gross mean (Milion USD)')
plt.show()

# %%
imdb_duration = eda.groupby('duration_type').agg(imdb=('imdb_score','mean')).reset_index()
imdb_duration
# Out:
#   duration_type      imdb
# 0          long  6.940185
# 1        medium  6.394737
# 2         short  6.024791

# %%
eda[['movie_title', 'num_critic_for_reviews', 'num_voted_users', 'num_user_for_reviews']].head(5)
# Out:
#                                  movie_title  num_critic_for_reviews  \
# 0                                    Avatar                    723.0
# 1  Pirates of the Caribbean: At World's End                    302.0
# 2                                   Spectre                    602.0
# 3                     The Dark Knight Rises                    813.0
# 5                               John Carter                    462.0
#
#    num_voted_users  num_user_for_reviews
# 0           886204                3054.0
# 1           471220                1238.0
# 2           275868                 994.0
# 3          1144337                2701.0
# 5           212204                 738.0

# %%
eda['percent_critic'] = eda['num_critic_for_reviews']/eda['num_user_for_reviews']*100
eda['percent_critic'] = eda['percent_critic'].astype(int)

eda_critic = eda[['movie_title', 'percent_critic']].sort_values(by='percent_critic', ascending=False).reset_index(drop=True)
# we should filter percent < 100, we think that it's not possible if num_critic_for_reviews > num_user_review 
eda_critic = eda_critic[eda_critic['percent_critic'] <= 100].reset_index(drop=True)
eda_critic.head(10)
# Out:
#                     movie_title  percent_critic
# 0  Love in the Time of Cholera              100
# 1     The Life Before Her Eyes              100
# 2              Project Almanac              100
# 3              I Love You, Man              100
# 4                  The Funeral              100
# 5      The Man from U.N.C.L.E.              100
# 6                    The Judge              100
# 7             The Longest Ride              100
# 8                         Hugo              100
# 9                 The Dictator              100

# %%
eda['critic'] = np.where(eda['percent_critic'] <= 10, 1,
                       np.where((eda['percent_critic']>10) & (eda['percent_critic']<=20),2,
                       np.where((eda['percent_critic']>20) & (eda['percent_critic']<=30),3,
                       np.where((eda['percent_critic']>30) & (eda['percent_critic']<=40),4,
                       np.where((eda['percent_critic']>40) & (eda['percent_critic']<=50),5,
                       np.where((eda['percent_critic']>50) & (eda['percent_critic']<=60),6,
                       np.where((eda['percent_critic']>60) & (eda['percent_critic']<=70),7,
                       np.where((eda['percent_critic']>70) & (eda['percent_critic']<=80),8,
                       np.where((eda['percent_critic']>80) & (eda['percent_critic']<=90),9,10
                       )))))))))

# %%
eda_binned = eda[eda['percent_critic']<=100].reset_index(drop=True)
eda_binned.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes   gross                           genres  \
# 0                  1000.0  760.51  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309.40         Action|Adventure|Fantasy
# 2                 11000.0  200.07        Action|Adventure|Thriller
# 3                 27000.0  448.13                  Action|Thriller
# 4                   640.0   73.06          Action|Adventure|Sci-Fi
#
#       actor_1_name                                movie_title  \
# 0      CCH Pounder                                    Avatar
# 1      Johnny Depp  Pirates of the Caribbean: At World's End
# 2  Christoph Waltz                                   Spectre
# 3        Tom Hardy                     The Dark Knight Rises
# 4     Daryl Sabara                               John Carter
#
#    num_voted_users  cast_total_facebook_likes          actor_3_name  \
# 0           886204                       4834             Wes Studi
# 1           471220                      48350        Jack Davenport
# 2           275868                      11700      Stephanie Sigman
# 3          1144337                     106759  Joseph Gordon-Levitt
# 4           212204                       1873          Polly Walker
#
#    facenumber_in_poster                                      plot_keywords  \
# 0                   0.0             avatar|future|marine|native|paraplegic
# 1                   0.0  goddess|marriage ceremony|marriage proposal|pi...
# 2                   1.0                bomb|espionage|sequel|spy|terrorist
# 3                   0.0  deception|imprisonment|lawlessness|police offi...
# 4                   1.0  alien|american civil war|male nipple|mars|prin...
#
#                                      movie_imdb_link  num_user_for_reviews  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...                3054.0
# 1  http://www.imdb.com/title/tt0449088/?ref_=fn_t...                1238.0
# 2  http://www.imdb.com/title/tt2379713/?ref_=fn_t...                 994.0
# 3  http://www.imdb.com/title/tt1345836/?ref_=fn_t...                2701.0
# 4  http://www.imdb.com/title/tt0401729/?ref_=fn_t...                 738.0
#
#   language country content_rating       budget  title_year  \
# 0  English     USA          PG-13  237000000.0        2009
# 1  English     USA          PG-13  300000000.0        2007
# 2  English      UK          PG-13  245000000.0        2015
# 3  English     USA          PG-13  250000000.0        2012
# 4  English     USA          PG-13  263700000.0        2012
#
#    actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes  \
# 0                   936.0         7.9          1.78                 33000
# 1                  5000.0         7.1          2.35                     0
# 2                   393.0         6.8          2.35                 85000
# 3                 23000.0         8.5          2.35                164000
# 4                   632.0         6.6          2.35                 24000
#
#    profit languages duration_type  percent_critic  critic
# 0  523.51   English          long              23       3
# 1    9.40   English          long              24       3
# 2  -44.93   English          long              60       6
# 3  198.13   English          long              30       3
# 4 -190.64   English          long              62       7

# %%
critic_binned = eda_binned.groupby('critic').agg(count=('critic','count')).reset_index()
critic_binned
# Out:
#    critic  count
# 0       1     30
# 1       2    184
# 2       3    396
# 3       4    527
# 4       5    429
# 5       6    363
# 6       7    284
# 7       8    251
# 8       9    167
# 9      10    169

# %%
sns.barplot(x='critic', y='count', data=critic_binned, palette='Blues')
# Out:
# <AxesSubplot:xlabel='critic', ylabel='count'>

# %%
critic_gross = eda_binned.groupby('critic').agg(gross_sum=('gross','sum'), gross_mean=('gross','mean')).reset_index()
critic_gross
# Out:
#    critic  gross_sum  gross_mean
# 0       1    4156.17  138.539000
# 1       2   17256.16   93.783478
# 2       3   28988.79   73.204015
# 3       4   30323.32   57.539507
# 4       5   25577.81   59.621935
# 5       6   18951.56   52.208154
# 6       7   14722.73   51.840599
# 7       8   10119.12   40.315219
# 8       9    7151.11   42.821018
# 9      10    8073.10   47.769822

# %%
sns.barplot(x='critic', y='gross_sum', data=critic_gross, palette='Blues')
plt.title('Sum Gross by Critic Review Rank (in Milion USD)', fontsize=15)
plt.show()

sns.barplot(x='critic', y='gross_mean', data=critic_gross, palette='Blues')
plt.title('Avg Gross by Critic Review Rank (in Milion USD)', fontsize=15)
plt.show()

# %%
prof = eda_binned.groupby('critic').agg(profit_sum=('profit','sum'), profit_mean=('profit','mean')).reset_index()
prof
# Out:
#    critic  profit_sum  profit_mean
# 0       1     1887.68    62.922667
# 1       2     6337.89    34.445054
# 2       3    10331.51    26.089672
# 3       4     9328.20    17.700569
# 4       5     8553.65    19.938578
# 5       6     3625.88     9.988650
# 6       7     2057.24     7.243803
# 7       8      446.29     1.778048
# 8       9     -100.03    -0.598982
# 9      10     1007.10     5.959172

# %%
sns.barplot(x='critic', y='profit_sum', data=prof, palette='Blues')
plt.title('Profit by Critic Review Rank (in Milion USD)', fontsize=15)
plt.show()

sns.barplot(x='critic', y='profit_mean', data=prof, palette='Blues')
plt.title('Profit by Critic Review Rank (in Milion USD)', fontsize=15)
plt.show()

# %%
critic_imdb = eda_binned.groupby('critic').agg(imdb=('imdb_score','mean')).reset_index()
critic_imdb
# Out:
#    critic      imdb
# 0       1  7.423333
# 1       2  6.783152
# 2       3  6.697980
# 3       4  6.493928
# 4       5  6.423077
# 5       6  6.332507
# 6       7  6.309507
# 7       8  6.398406
# 8       9  6.479641
# 9      10  6.444379

# %%
sns.barplot(x='critic', y='imdb', data=critic_imdb, palette='Blues')
plt.title('IMDB score by Critic Review Rank', fontsize=15)
# Out:
# Text(0.5, 1.0, 'IMDB score by Critic Review Rank')

# %%
eda['genres'].value_counts()
# Out:
# Comedy|Drama|Romance                     147
# Drama                                    140
# Comedy|Drama                             137
# Comedy                                   137
# Comedy|Romance                           131
#                                         ...
# Action|Thriller|Western                    1
# Action|Family|Fantasy|Musical              1
# Action|Adventure|Drama|Family              1
# Animation|Comedy|Family|Music|Romance      1
# Comedy|Crime|Horror                        1
# Name: genres, Length: 745, dtype: int64

# %%
eda['genres'].str.split('|')[0]
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']

# %%
eda['genre'] = eda['genres'].str.split('|')
eda['genre1'] = eda['genre'].apply(lambda x: x[0])

# Some of the movies have only one genre. In such cases, assign the same genre to 'genre_2' as well
eda['genre2'] = eda['genre'].apply(lambda x: x[1] if len(x) > 1 else x[0])
eda['genre3'] = eda['genre'].apply(lambda x: x[2] if len(x) > 2 else x[0])
eda['genre4'] = eda['genre'].apply(lambda x: x[3] if len(x) > 3 else x[0])
eda['genre5'] = eda['genre'].apply(lambda x: x[5] if len(x) > 5 else x[0])

eda[['genres', 'genre1', 'genre2', 'genre3', 'genre4', 'genre5']].head(5)
# Out:
#                             genres  genre1     genre2    genre3  genre4  \
# 0  Action|Adventure|Fantasy|Sci-Fi  Action  Adventure   Fantasy  Sci-Fi
# 1         Action|Adventure|Fantasy  Action  Adventure   Fantasy  Action
# 2        Action|Adventure|Thriller  Action  Adventure  Thriller  Action
# 3                  Action|Thriller  Action   Thriller    Action  Action
# 5          Action|Adventure|Sci-Fi  Action  Adventure    Sci-Fi  Action
#
#    genre5
# 0  Action
# 1  Action
# 2  Action
# 3  Action
# 5  Action

# %%
eda.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 5                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes   gross                           genres  \
# 0                  1000.0  760.51  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309.40         Action|Adventure|Fantasy
# 2                 11000.0  200.07        Action|Adventure|Thriller
# 3                 27000.0  448.13                  Action|Thriller
# 5                   640.0   73.06          Action|Adventure|Sci-Fi
#
#       actor_1_name                                movie_title  \
# 0      CCH Pounder                                    Avatar
# 1      Johnny Depp  Pirates of the Caribbean: At World's End
# 2  Christoph Waltz                                   Spectre
# 3        Tom Hardy                     The Dark Knight Rises
# 5     Daryl Sabara                               John Carter
#
#    num_voted_users  cast_total_facebook_likes          actor_3_name  \
# 0           886204                       4834             Wes Studi
# 1           471220                      48350        Jack Davenport
# 2           275868                      11700      Stephanie Sigman
# 3          1144337                     106759  Joseph Gordon-Levitt
# 5           212204                       1873          Polly Walker
#
#    facenumber_in_poster                                      plot_keywords  \
# 0                   0.0             avatar|future|marine|native|paraplegic
# 1                   0.0  goddess|marriage ceremony|marriage proposal|pi...
# 2                   1.0                bomb|espionage|sequel|spy|terrorist
# 3                   0.0  deception|imprisonment|lawlessness|police offi...
# 5                   1.0  alien|american civil war|male nipple|mars|prin...
#
#                                      movie_imdb_link  num_user_for_reviews  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...                3054.0
# 1  http://www.imdb.com/title/tt0449088/?ref_=fn_t...                1238.0
# 2  http://www.imdb.com/title/tt2379713/?ref_=fn_t...                 994.0
# 3  http://www.imdb.com/title/tt1345836/?ref_=fn_t...                2701.0
# 5  http://www.imdb.com/title/tt0401729/?ref_=fn_t...                 738.0
#
#   language country content_rating       budget  title_year  \
# 0  English     USA          PG-13  237000000.0        2009
# 1  English     USA          PG-13  300000000.0        2007
# 2  English      UK          PG-13  245000000.0        2015
# 3  English     USA          PG-13  250000000.0        2012
# 5  English     USA          PG-13  263700000.0        2012
#
#    actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes  \
# 0                   936.0         7.9          1.78                 33000
# 1                  5000.0         7.1          2.35                     0
# 2                   393.0         6.8          2.35                 85000
# 3                 23000.0         8.5          2.35                164000
# 5                   632.0         6.6          2.35                 24000
#
#    profit languages duration_type  percent_critic  critic  \
# 0  523.51   English          long              23       3
# 1    9.40   English          long              24       3
# 2  -44.93   English          long              60       6
# 3  198.13   English          long              30       3
# 5 -190.64   English          long              62       7
#
#                                   genre  genre1     genre2    genre3  genre4  \
# 0  [Action, Adventure, Fantasy, Sci-Fi]  Action  Adventure   Fantasy  Sci-Fi
# 1          [Action, Adventure, Fantasy]  Action  Adventure   Fantasy  Action
# 2         [Action, Adventure, Thriller]  Action  Adventure  Thriller  Action
# 3                    [Action, Thriller]  Action   Thriller    Action  Action
# 5           [Action, Adventure, Sci-Fi]  Action  Adventure    Sci-Fi  Action
#
#    genre5
# 0  Action
# 1  Action
# 2  Action
# 3  Action
# 5  Action

# %%
gen = eda.groupby('genre1').agg(count=('genre1','count')).reset_index()
gen
# Out:
#          genre1  count
# 0        Action    951
# 1     Adventure    366
# 2     Animation     45
# 3     Biography    204
# 4        Comedy    984
# 5         Crime    253
# 6   Documentary     26
# 7         Drama    659
# 8        Family      3
# 9       Fantasy     37
# 10       Horror    159
# 11      Musical      2
# 12      Mystery     23
# 13      Romance      1
# 14       Sci-Fi      7
# 15     Thriller      1
# 16      Western      2

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='count', y='genre1', data=gen)
# Out:
# <AxesSubplot:xlabel='count', ylabel='genre1'>

# %%
gross_genre = eda.groupby('genre1').agg(gross_sum=('gross','sum'),gross_mean=('gross','mean')).reset_index()
gross_genre
# Out:
#          genre1  gross_sum  gross_mean
# 0        Action   73573.83   77.364700
# 1     Adventure   32585.54   89.031530
# 2     Animation    4057.77   90.172667
# 3     Biography    7434.08   36.441569
# 4        Comedy   38588.87   39.216331
# 5         Crime    8310.37   32.847312
# 6   Documentary     529.70   20.373077
# 7         Drama   21191.50   32.157056
# 8        Family     447.48  149.160000
# 9       Fantasy    1497.85   40.482432
# 10       Horror    5492.88   34.546415
# 11      Musical     184.17   92.085000
# 12      Mystery    1171.72   50.944348
# 13      Romance      62.45   62.450000
# 14       Sci-Fi     208.56   29.794286
# 15     Thriller       0.00    0.000000
# 16      Western      47.50   23.750000

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='gross_sum', y='genre1', data=gross_genre, palette='Blues')
plt.title('Gross Total Per Genre (In Milion)')
plt.show()

plt.figure(figsize=(10,6))
sns.barplot(x='gross_mean', y='genre1', data=gross_genre, palette='Blues')
plt.title('Avg Gross Per Genre (In Milion)')
plt.show()

# %%
profit_genre = eda.groupby('genre1').agg(profit_sum=('profit','sum'),profit_mean=('profit','mean')).reset_index()
profit_genre
# Out:
#          genre1  profit_sum  profit_mean
# 0        Action     5493.50     5.776551
# 1     Adventure     6383.56    17.441421
# 2     Animation     1514.32    33.651556
# 3     Biography     2213.04    10.848235
# 4        Comedy     3132.06     3.182988
# 5         Crime    -2377.36    -9.396680
# 6   Documentary      334.10    12.850000
# 7         Drama     1356.66     2.058665
# 8        Family      402.98   134.326667
# 9       Fantasy      899.85    24.320270
# 10       Horror     3283.94    20.653711
# 11      Musical      177.79    88.895000
# 12      Mystery      387.85    16.863043
# 13      Romance       12.25    12.250000
# 14       Sci-Fi       14.46     2.065714
# 15     Thriller       -0.30    -0.300000
# 16      Western       39.40    19.700000

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='profit_sum', y='genre1', data=profit_genre, palette='Blues')
plt.title('Profit Total Per Genre (In Milion)')
plt.show()

plt.figure(figsize=(10,6))
sns.barplot(x='profit_mean', y='genre1', data=profit_genre, palette='Blues')
plt.title('Avg Profit Per Genre (In Milion)')
plt.show()

# %%
imdb_genre = eda.groupby('genre1').agg(imdb_score=('imdb_score','mean')).reset_index()
imdb_genre
# Out:
#          genre1  imdb_score
# 0        Action    6.289905
# 1     Adventure    6.558470
# 2     Animation    6.740000
# 3     Biography    7.158824
# 4        Comedy    6.169004
# 5         Crime    6.936364
# 6   Documentary    6.796154
# 7         Drama    6.831866
# 8        Family    6.500000
# 9       Fantasy    6.281081
# 10       Horror    5.842138
# 11      Musical    6.750000
# 12      Mystery    6.652174
# 13      Romance    7.100000
# 14       Sci-Fi    6.628571
# 15     Thriller    4.800000
# 16      Western    8.100000

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='imdb_score', y='genre1', data=imdb_genre, palette='Blues')
plt.show()

# %%
data.dropna(inplace = True)
data['title_year'] = data['title_year'].astype(int)
data['title_year'].dtypes
# Out:
# dtype('int32')

# %%
import pandas as pd
from ipywidgets import interact

# Set the display option for maximum rows in pandas
pd.set_option('display.max_rows', 30)

# Sample DataFrame for demonstration (replace this with your actual DataFrame)
eda = pd.DataFrame({
    'language': ['English', 'French', 'Spanish', 'English', 'French', 'Spanish', 'English', 'French', 'Spanish'],
    'movie_title': ['Movie1', 'Movie2', 'Movie3', 'Movie4', 'Movie5', 'Movie6', 'Movie7', 'Movie8', 'Movie9'],
    'imdb_score': [7.2, 6.8, 7.9, 8.1, 5.4, 7.0, 6.5, 8.3, 7.6]
})

@interact
def lang(Language=list(eda['language'].value_counts().index)):
    return eda.loc[(eda['language'] == Language)].head(10)[['movie_title', 'imdb_score']
                                                          ].sort_values(by='imdb_score', ascending=False).reset_index(drop=True)
# Out:
# interactive(children=(Dropdown(description='Language', options=('English', 'French', 'Spanish'), value='Englis…

# %%
from matplotlib import image
import matplotlib.pyplot as plt
import os

downloads_path = os.path.join(os.path.expanduser("~"), "Downloads")

fig = plt.figure(figsize=(20, 14))

rows = 1
columns = 3

# images
img1 = image.imread(os.path.join(downloads_path, 'French.png'))
img2 = image.imread(os.path.join(downloads_path, 'Spanish.png'))
img3 = image.imread(os.path.join(downloads_path, 'English.png'))

fig.add_subplot(rows, columns, 1)

plt.imshow(img1)
plt.axis('off')
plt.title('This function above will be shown like this :')

fig.add_subplot(rows, columns, 2)

plt.imshow(img2)
plt.axis('off')
plt.title('This function above will be shown like this :')

fig.add_subplot(rows, columns, 3)

plt.imshow(img3)
plt.axis('off')
plt.title('This function above will be shown like this :')

plt.show()

# %%
import pandas as pd
from ipywidgets import interact

pd.set_option('display.max_rows', 150)
pd.set_option('display.max_colwidth', 150)

data = pd.DataFrame({
    'director_name': ['Director A', 'Director B', 'Director A', 'Director C', 'Director B', 'Director A'],
    'movie_title': ['Movie1', 'Movie2', 'Movie3', 'Movie4', 'Movie5', 'Movie6'],
    'title_year': [2001, 2002, 2003, 2004, 2005, 2006],
    'imdb_score': [7.2, 6.8, 7.9, 8.1, 5.4, 7.0]
})

@interact
def director(Director = list(data['director_name'].value_counts().index)):
    return data.loc[(data['director_name'] == Director)][
        ['movie_title', 'title_year', 'imdb_score']].sort_values(by='imdb_score', 
                                                                ascending=False).head(10).reset_index(drop=True)
# Out:
# interactive(children=(Dropdown(description='Director', options=('Director A', 'Director B', 'Director C'), val…

# %%
from matplotlib import image
import matplotlib.pyplot as plt
import os

downloads_path = os.path.join(os.path.expanduser("~"), "Downloads")

fig = plt.figure(figsize=(20, 14))

rows = 1
columns = 3

img1 = image.imread(os.path.join(downloads_path, 'Steven.png'))
img2 = image.imread(os.path.join(downloads_path, 'Woody.png'))
img3 = image.imread(os.path.join(downloads_path, 'Clint.png'))

fig.add_subplot(rows, columns, 1)

plt.imshow(img1)
plt.axis('off')
plt.title('This function above will be shown like this :')

fig.add_subplot(rows, columns, 2)

plt.imshow(img2)
plt.axis('off')
plt.title('This function above will be shown like this :')

fig.add_subplot(rows, columns, 3)

plt.imshow(img3)
plt.axis('off')
plt.title('This function above will be shown like this :')

plt.show()

# %%
import pandas as pd
from ipywidgets import interact

pd.set_option('display.max_rows', 150)
pd.set_option('display.max_colwidth', 150)

df = pd.DataFrame({
    'joblocation_address': ['City1', 'City2', 'City1', 'City3', 'City2', 'City1'],
    'industry': ['Industry1', 'Industry2', 'Industry1', 'Industry3', 'Industry2', 'Industry1'],
    'experience_min': [2, 3, 5, 1, 4, 2],
    'numberofpositions': [15, 10, 8, 20, 5, 12],
    'company': ['Company1', 'Company2', 'Company3', 'Company4', 'Company5', 'Company6'],
    'jobtitle': ['Title1', 'Title2', 'Title3', 'Title4', 'Title5', 'Title6'],
    'education': ['Edu1', 'Edu2', 'Edu3', 'Edu4', 'Edu5', 'Edu6'],
    'payrate': [50000, 60000, 55000, 70000, 45000, 52000]
})

@interact
def check(City = list(df['joblocation_address'].value_counts().index),
          Industry = list(df['industry'].value_counts().index),
          Experience = list(df['experience_min'].value_counts().sort_values(ascending=False).index),
          Vacancies = 10):
    return df.loc[(df['numberofpositions'] > Vacancies)
                  & (df['joblocation_address'] == City)
                  & (df['industry'] == Industry)
                  & (df['experience_min'] == Experience)][[
                                                         'company',
                                                         'jobtitle',
                                                         'education',
                                                         'payrate',
                                                         'numberofpositions']]
# Out:
# interactive(children=(Dropdown(description='City', options=('City1', 'City2', 'City3'), value='City1'), Dropdo…

# %%
import pandas as pd
from ipywidgets import interact

pd.set_option('display.max_rows', 150)

data = pd.DataFrame({
    'actor_1_name': ['Actor A', 'Actor B', 'Actor A', 'Actor C', 'Actor B', 'Actor A'],
    'actor_2_name': ['Actor D', 'Actor E', 'Actor F', 'Actor G', 'Actor H', 'Actor I'],
    'actor_3_name': ['Actor J', 'Actor K', 'Actor L', 'Actor M', 'Actor N', 'Actor O'],
    'movie_title': ['Movie1', 'Movie2', 'Movie3', 'Movie4', 'Movie5', 'Movie6'],
    'title_year': [2001, 2002, 2003, 2004, 2005, 2006],
    'imdb_score': [7.2, 6.8, 7.9, 8.1, 5.4, 7.0]
})

@interact
def actor(Actor = list(data['actor_1_name'].value_counts().index)):
    data_combined = pd.concat([data[['actor_1_name', 'movie_title', 'title_year', 'imdb_score']].rename(columns={'actor_1_name': 'actor'}),
                               data[['actor_2_name', 'movie_title', 'title_year', 'imdb_score']].rename(columns={'actor_2_name': 'actor'}),
                               data[['actor_3_name', 'movie_title', 'title_year', 'imdb_score']].rename(columns={'actor_3_name': 'actor'})])

    return data_combined.loc[data_combined['actor'] == Actor][['movie_title','title_year','imdb_score']
                                                             ].sort_values(by='imdb_score', ascending=False).reset_index(drop=True).head(10)
# Out:
# interactive(children=(Dropdown(description='Actor', options=('Actor A', 'Actor B', 'Actor C'), value='Actor A'…

# %%
from matplotlib import image
import matplotlib.pyplot as plt
import os

downloads_path = os.path.join(os.path.expanduser("~"), "Downloads")

fig = plt.figure(figsize=(20, 14))

rows = 1
columns = 3

img1 = image.imread(os.path.join(downloads_path, 'RD.png'))
img2 = image.imread(os.path.join(downloads_path, 'JS.png'))
img3 = image.imread(os.path.join(downloads_path, 'JD.png'))

fig.add_subplot(rows, columns, 1)

plt.imshow(img1)
plt.axis('off')
plt.title('This function above will be shown like this :')

fig.add_subplot(rows, columns, 2)

plt.imshow(img2)
plt.axis('off')
plt.title('This function above will be shown like this :')

fig.add_subplot(rows, columns, 3)

plt.imshow(img3)
plt.axis('off')
plt.title('This function above will be shown like this :')

plt.show()

# %%
# lets read the dataset
df = pd.read_csv('movie_metadata.csv')

# %%
from mlxtend.preprocessing import TransactionEncoder

x = df['genres'].str.split('|')
te = TransactionEncoder()
x = te.fit_transform(x)
x = pd.DataFrame(x, columns=te.columns_)

# Let's convert this data into boolean so that we can perform calculations
genres = x.astype('int')

# Now, let's insert the movie titles in the first column
genres.insert(0, 'movie_title', df['movie_title'])

# Let's set these movie titles as index of the data
genres = genres.set_index('movie_title')

genres.head()
# Out:
#                                                          Action  Adventure  \
# movie_title
# Avatar                                                        1          1
# Pirates of the Caribbean: At World's End                      1          1
# Spectre                                                       1          1
# The Dark Knight Rises                                         1          0
# Star Wars: Episode VII - The Force Awakens                    0          0
#
#                                                          Animation  Biography  \
# movie_title
# Avatar                                                           0          0
# Pirates of the Caribbean: At World's End                         0          0
# Spectre                                                          0          0
# The Dark Knight Rises                                            0          0
# Star Wars: Episode VII - The Force Awakens                       0          0
#
#                                                          Comedy  Crime  \
# movie_title
# Avatar                                                        0      0
# Pirates of the Caribbean: At World's End                      0      0
# Spectre                                                       0      0
# The Dark Knight Rises                                         0      0
# Star Wars: Episode VII - The Force Awakens                    0      0
#
#                                                          Documentary  Drama  \
# movie_title
# Avatar                                                             0      0
# Pirates of the Caribbean: At World's End                           0      0
# Spectre                                                            0      0
# The Dark Knight Rises                                              0      0
# Star Wars: Episode VII - The Force Awakens                         1      0
#
#                                                          Family  Fantasy  \
# movie_title
# Avatar                                                        0        1
# Pirates of the Caribbean: At World's End                      0        1
# Spectre                                                       0        0
# The Dark Knight Rises                                         0        0
# Star Wars: Episode VII - The Force Awakens                    0        0
#
#                                                          Film-Noir  Game-Show  \
# movie_title
# Avatar                                                           0          0
# Pirates of the Caribbean: At World's End                         0          0
# Spectre                                                          0          0
# The Dark Knight Rises                                            0          0
# Star Wars: Episode VII - The Force Awakens                       0          0
#
#                                                          History  Horror  \
# movie_title
# Avatar                                                         0       0
# Pirates of the Caribbean: At World's End                       0       0
# Spectre                                                        0       0
# The Dark Knight Rises                                          0       0
# Star Wars: Episode VII - The Force Awakens                     0       0
#
#                                                          Music  Musical  \
# movie_title
# Avatar                                                       0        0
# Pirates of the Caribbean: At World's End                     0        0
# Spectre                                                      0        0
# The Dark Knight Rises                                        0        0
# Star Wars: Episode VII - The Force Awakens                   0        0
#
#                                                          Mystery  News  \
# movie_title
# Avatar                                                         0     0
# Pirates of the Caribbean: At World's End                       0     0
# Spectre                                                        0     0
# The Dark Knight Rises                                          0     0
# Star Wars: Episode VII - The Force Awakens                     0     0
#
#                                                          Reality-TV  Romance  \
# movie_title
# Avatar                                                            0        0
# Pirates of the Caribbean: At World's End                          0        0
# Spectre                                                           0        0
# The Dark Knight Rises                                             0        0
# Star Wars: Episode VII - The Force Awakens                        0        0
#
#                                                          Sci-Fi  Short  Sport  \
# movie_title
# Avatar                                                        1      0      0
# Pirates of the Caribbean: At World's End                      0      0      0
# Spectre                                                       0      0      0
# The Dark Knight Rises                                         0      0      0
# Star Wars: Episode VII - The Force Awakens                    0      0      0
#
#                                                          Thriller  War  \
# movie_title
# Avatar                                                          0    0
# Pirates of the Caribbean: At World's End                        0    0
# Spectre                                                         1    0
# The Dark Knight Rises                                           1    0
# Star Wars: Episode VII - The Force Awakens                      0    0
#
#                                                          Western
# movie_title
# Avatar                                                         0
# Pirates of the Caribbean: At World's End                       0
# Spectre                                                        0
# The Dark Knight Rises                                          0
# Star Wars: Episode VII - The Force Awakens                     0

# %%
# lets make a sparse matrix to recommend the movies

x = genres.transpose()
x.head()
# Out:
# movie_title  Avatar   Pirates of the Caribbean: At World's End   Spectre   \
# Action             1                                          1         1
# Adventure          1                                          1         1
# Animation          0                                          0         0
# Biography          0                                          0         0
# Comedy             0                                          0         0
#
# movie_title  The Dark Knight Rises   \
# Action                            1
# Adventure                         0
# Animation                         0
# Biography                         0
# Comedy                            0
#
# movie_title  Star Wars: Episode VII - The Force Awakens               \
# Action                                                             0
# Adventure                                                          0
# Animation                                                          0
# Biography                                                          0
# Comedy                                                             0
#
# movie_title  John Carter   Spider-Man 3   Tangled   Avengers: Age of Ultron   \
# Action                  1              1         0                         1
# Adventure               1              1         1                         1
# Animation               0              0         1                         0
# Biography               0              0         0                         0
# Comedy                  0              0         1                         0
#
# movie_title  Harry Potter and the Half-Blood Prince   \
# Action                                             0
# Adventure                                          1
# Animation                                          0
# Biography                                          0
# Comedy                                             0
#
# movie_title  Batman v Superman: Dawn of Justice   Superman Returns   \
# Action                                         1                  1
# Adventure                                      1                  1
# Animation                                      0                  0
# Biography                                      0                  0
# Comedy                                         0                  0
#
# movie_title  Quantum of Solace   Pirates of the Caribbean: Dead Man's Chest   \
# Action                        1                                            1
# Adventure                     1                                            1
# Animation                     0                                            0
# Biography                     0                                            0
# Comedy                        0                                            0
#
# movie_title  The Lone Ranger   Man of Steel   \
# Action                      1              1
# Adventure                   1              1
# Animation                   0              0
# Biography                   0              0
# Comedy                      0              0
#
# movie_title  The Chronicles of Narnia: Prince Caspian   The Avengers   \
# Action                                               1              1
# Adventure                                            1              1
# Animation                                            0              0
# Biography                                            0              0
# Comedy                                               0              0
#
# movie_title  Pirates of the Caribbean: On Stranger Tides   Men in Black 3   \
# Action                                                  1                1
# Adventure                                               1                1
# Animation                                               0                0
# Biography                                               0                0
# Comedy                                                  0                1
#
# movie_title  The Hobbit: The Battle of the Five Armies   \
# Action                                                0
# Adventure                                             1
# Animation                                             0
# Biography                                             0
# Comedy                                                0
#
# movie_title  The Amazing Spider-Man   Robin Hood   \
# Action                             1            1
# Adventure                          1            1
# Animation                          0            0
# Biography                          0            0
# Comedy                             0            0
#
# movie_title  The Hobbit: The Desolation of Smaug   The Golden Compass   ...  \
# Action                                          0                    0  ...
# Adventure                                       1                    1  ...
# Animation                                       0                    0  ...
# Biography                                       0                    0  ...
# Comedy                                          0                    0  ...
#
# movie_title  Flywheel   Exeter   The Ridges   The Puffy Chair   \
# Action               0        0            0                 0
# Adventure            0        0            0                 0
# Animation            0        0            0                 0
# Biography            0        0            0                 0
# Comedy               0        0            0                 1
#
# movie_title  Stories of Our Lives   Breaking Upwards   \
# Action                           0                  0
# Adventure                        0                  0
# Animation                        0                  0
# Biography                        0                  0
# Comedy                           0                  0
#
# movie_title  All Superheroes Must Die   Pink Flamingos   Clean   The Circle   \
# Action                               0                0       0            0
# Adventure                            0                0       0            0
# Animation                            0                0       0            0
# Biography                            0                0       0            0
# Comedy                               0                1       0            0
#
# movie_title  Tin Can Man   The Cure   On the Downlow   \
# Action                  0          0                0
# Adventure               0          0                0
# Animation               0          0                0
# Biography               0          0                0
# Comedy                  0          0                0
#
# movie_title  Sanctuary; Quite a Conundrum   Bang   Primer   Cavite   \
# Action                                   0      0        0        0
# Adventure                                0      0        0        0
# Animation                                0      0        0        0
# Biography                                0      0        0        0
# Comedy                                   1      0        0        0
#
# movie_title  El Mariachi   The Mongol King   Newlyweds   \
# Action                  1                 0           0
# Adventure               0                 0           0
# Animation               0                 0           0
# Biography               0                 0           0
# Comedy                  0                 0           1
#
# movie_title  Signed Sealed Delivered   The Following               \
# Action                              0                           0
# Adventure                           0                           0
# Animation                           0                           0
# Biography                           0                           0
# Comedy                              1                           0
#
# movie_title  A Plague So Pleasant   Shanghai Calling   My Date with Drew
# Action                           0                  0                   0
# Adventure                        0                  0                   0
# Animation                        0                  0                   0
# Biography                        0                  0                   0
# Comedy                           0                  1                   0
#
# [5 rows x 5043 columns]

# %%
pd.set_option('max_rows', 150)
pd.set_option('max_colwidth', 150)
@interact

def director(Director = list(data['director_name'].value_counts().index)):
    return data.loc[(data['director_name'] == Director)][
        ['movie_title','title_year', 'imdb_score']].sort_values(by='imdb_score', 
                                                                ascending=False).head(10).reset_index(drop=True)

# %%
pd.set_option('max_rows', 150)
pd.set_option('max_colwidth', 150)
@interact

def rec_mov(List_Movies=list(data['movie_title'].sort_values().values)):
    return data.loc[(data['movie_title'] == List_Movies)][
        ['movie_title','title_year', 'imdb_score']].sort_values(by='movie_title', ascending=True).reset_index(drop=True)

# %%
# making a recommendation engine for getting similar movies

def recommendation_movie(movie):    
    movie = x[movie+'\xa0']
    similar_movies = x.corrwith(movie)
    similar_movies = similar_movies.sort_values(ascending=False)
    similar_movies = similar_movies.iloc[1:]
    return similar_movies.head(20)

# %%
# lets test on some results
recommendation_movie('Pacific Rim')
# Out:
# movie_title
# Battlefield Earth                       1.0
# Beneath the Planet of the Apes          1.0
# The Time Machine                        1.0
# Iron Man 2                              1.0
# The Avengers                            1.0
# Transformers: Revenge of the Fallen     1.0
# Transformers: Age of Extinction         1.0
# Fantastic Four                          1.0
# TRON: Legacy                            1.0
# Green Lantern                           1.0
# Edge of Tomorrow                        1.0
# Terminator Salvation                    1.0
# Logan's Run                             1.0
# Wing Commander                          1.0
# The Fifth Element                       1.0
# Star Trek Into Darkness                 1.0
# Flash Gordon                            1.0
# X-Men                                   1.0
# Pacific Rim                             1.0
# Transformers: Dark of the Moon          1.0
# dtype: float64

# %%
# lets test on some results
recommendation_movie('Captain America: Civil War')
# Out:
# movie_title
# Battlefield Earth                       1.0
# Beneath the Planet of the Apes          1.0
# The Time Machine                        1.0
# Iron Man 2                              1.0
# The Avengers                            1.0
# Transformers: Revenge of the Fallen     1.0
# Transformers: Age of Extinction         1.0
# Fantastic Four                          1.0
# TRON: Legacy                            1.0
# Green Lantern                           1.0
# Edge of Tomorrow                        1.0
# Terminator Salvation                    1.0
# Logan's Run                             1.0
# Wing Commander                          1.0
# The Fifth Element                       1.0
# Star Trek Into Darkness                 1.0
# Flash Gordon                            1.0
# X-Men                                   1.0
# Pacific Rim                             1.0
# Transformers: Dark of the Moon          1.0
# dtype: float64
